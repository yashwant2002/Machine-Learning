# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
titanic = pd.read_csv("train.csv")

# %%
flights = sns.load_dataset("flights")

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# ### 1. Scatter Plot(Numerical - Numerical)

# %%
sns.scatterplot(x="total_bill", y="tip" ,data=tips , hue="sex", style="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 2. BarPlot (Numerical - Categorial)

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 823          824         1       3                       Moor, Mrs. (Beila)
# 525          526         0       3                       Farrell, Mr. James
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 442          443         0       3                Petterson, Mr. Johan Emil
#
#         Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 886    male  27.0      0      0  211536  13.000   NaN        S
# 823  female  27.0      0      1  392096  12.475  E121        S
# 525    male  40.5      0      0  367232   7.750   NaN        Q
# 850    male   4.0      4      2  347082  31.275   NaN        S
# 442    male  25.0      1      0  347076   7.775   NaN        S

# %%
sns.barplot(data=titanic, x="Pclass", y="Age", hue="Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### 3. Boxplot

# %%
sns.boxplot(data=titanic, x="Sex", y="Age")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### 4. Distplot ( Numerical - Categorical)

# %%
sns.distplot(titanic[titanic["Survived"]== 0]["Age"], hist=False)
sns.distplot(titanic[titanic["Survived"]== 1]["Age"], hist=False)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_6628\2344701445.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["Survived"]== 0]["Age"], hist=False)
# C:\Users\Yash\AppData\Local\Temp\ipykernel_6628\2344701445.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["Survived"]== 1]["Age"], hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

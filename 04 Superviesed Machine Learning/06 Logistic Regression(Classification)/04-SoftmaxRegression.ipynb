# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
encoder = LabelEncoder()
df["species"] = encoder.fit_transform(df["species"])

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 98            5.1          2.5           3.0          1.1        1
# 63            6.1          2.9           4.7          1.4        1
# 110           6.5          3.2           5.1          2.0        2
# 95            5.7          3.0           4.2          1.2        1
# 89            5.5          2.5           4.0          1.3        1

# %%
df = df[["sepal_length","petal_length", "species"]]

# %%
df.head()
# Out:
#    sepal_length  petal_length  species
# 0           5.1           1.4        0
# 1           4.9           1.4        0
# 2           4.7           1.3        0
# 3           4.6           1.5        0
# 4           5.0           1.4        0

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
clf = LogisticRegression()
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[14,  0,  0],
#        [ 0,  7,  1],
#        [ 0,  0,  8]])

# %%
#prediction
query = np.array([[3.4,2.7]])
clf.predict_proba(query)
# Out:
# c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[7.25865651e-01, 2.73720718e-01, 4.13631316e-04]])

# %%
clf.predict(query)
# Out:
# c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (3.0.2)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 7.1 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x.values, y.values, clf, legend=2)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.title("Softmax on iris")
plt.show()
# Out:
# c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

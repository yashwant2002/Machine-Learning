# %%
pip install opencv-python matplotlib numpy
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.9)
# Requirement already satisfied: numpy in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Yash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Yash\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.3/40.2 MB 10.2 MB/s eta 0:00:04
#    --- ------------------------------------ 3.1/40.2 MB 9.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.5/40.2 MB 8.1 MB/s eta 0:00:05
#    ------ --------------------------------- 6.3/40.2 MB 8.2 MB/s eta 0:00:05
#    -------- ------------------------------- 8.9/40.2 MB 8.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.3/40.2 MB 9.4 MB/s eta 0:00:04
#    ------------- -------------------------- 13.6/40.2 MB 9.7 MB/s eta 0:00:03
#    --------------- ------------------------ 15.7/40.2 MB 9.8 MB/s eta 0:00:03
#    ------------------ --------------------- 18.4/40.2 MB 10.0 MB/s eta 0:00:03
#    -------------------- ------------------- 20.4/40.2 MB 9.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.8/40.2 MB 10.1 MB/s eta 0:00:02
#    ------------------------ --------------- 24.9/40.2 MB 10.2 MB/s eta 0:00:02
#    --------------------------- ------------ 27.5/40.2 MB 10.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 29.6/40.2 MB 10.3 MB/s eta 0:00:02
#    ------------------------------- -------- 31.7/40.2 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 33.8/40.2 MB 10.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 35.9/40.2 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 37.5/40.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 10.0 MB/s  0:00:04
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt

# Load grayscale image
image = cv2.imread("sample.jpg", 0)

# Check image loaded
if image is None:
    print("Image not found")

else:

    # Shape
    print("Image Shape:", image.shape)

    # Brightest pixel
    print("Brightest Pixel:", image.max())

    # Darkest pixel
    print("Darkest Pixel:", image.min())

    # Average brightness
    print("Average Brightness:", image.mean())

    # Show image
    plt.imshow(image, cmap="gray")

    plt.title("Grayscale Image")

    plt.show()

    # Histogram
    plt.hist(image.ravel(), bins=256)

    plt.title("Pixel Distribution")

    plt.xlabel("Pixel Intensity")
    plt.ylabel("Frequency")

    plt.show()
# Out:
# Image Shape: (6000, 4000)
# Brightest Pixel: 255
# Darkest Pixel: 3
# Average Brightness: 102.029248375
